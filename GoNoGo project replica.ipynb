# %%
import numpy as np
from datascience import *
import pandas as pd
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from sklearn import *
from sklearn.model_selection import train_test_split
from datetime import datetime, timezone
import missingno as msno
import seaborn as sns
import math

# %%
gngData = pd.read_csv("Participant_984.csv")
unixStart = 1582733610
totalSecs = 2189
gngData['1'] = gngData['1']/50 + unixStart
gngData
# Out:
# C:\Users\Viraj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: DtypeWarning: Columns (33,60,61) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                    1           2          3           4          5  \
# 0       1.582734e+09  136.770523  61.213627  197.984146  75.556900
# 1       1.582734e+09  136.770523  61.213627  197.984146  75.556900
# 2       1.582734e+09  136.770523  61.213627  197.984146  75.556900
# 3       1.582734e+09  136.770523  61.213627  197.984146  75.556900
# 4       1.582734e+09  136.770523  61.213627  197.984146  75.556900
# ...              ...         ...        ...         ...        ...
# 109445  1.582736e+09   31.240822  11.728950   42.969772  19.511871
# 109446  1.582736e+09   31.196617  11.730339   42.926956  19.466278
# 109447  1.582736e+09   31.167786  11.740526   42.908310  19.427259
# 109448  1.582736e+09   31.138952  11.750713   42.889668  19.388239
# 109449  1.582736e+09   31.109165  11.747008   42.856175  19.362156
#
#                  6          7           8          9          10  ...  \
# 0       124.152428  63.146126  187.298447  61.006313  148.139404  ...
# 1       124.152428  63.146126  187.298447  61.006313  148.139404  ...
# 2       124.152428  63.146126  187.298447  61.006313  148.139404  ...
# 3       124.152428  63.146126  187.298447  61.006313  148.139404  ...
# 4       124.152428  63.146126  187.298447  61.006313  148.139404  ...
# ...            ...        ...         ...        ...         ...  ...
# 109445    8.391468   1.453402    9.844770   6.938075   36.472679  ...
# 109446    8.353993   1.445299    9.799192   6.908705   36.450577  ...
# 109447    8.324205   1.441594    9.765699   6.882621   36.421742  ...
# 109448    8.286732   1.433490    9.720122   6.853251   36.413101  ...
# 109449    8.250213   1.439278    9.689391   6.810945   36.375626  ...
#
#         Unnamed: 52  Unnamed: 53  Unnamed: 54  Unnamed: 55  Unnamed: 56  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 109445          NaN          NaN          NaN          NaN          NaN
# 109446          NaN          NaN          NaN          NaN          NaN
# 109447          NaN          NaN          NaN          NaN          NaN
# 109448          NaN          NaN          NaN          NaN          NaN
# 109449          NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 109445          NaN          NaN          NaN          NaN          NaN
# 109446          NaN          NaN          NaN          NaN          NaN
# 109447          NaN          NaN          NaN          NaN          NaN
# 109448          NaN          NaN          NaN          NaN          NaN
# 109449          NaN          NaN          NaN          NaN          NaN
#
# [109450 rows x 62 columns]

# %%
gngLog = pd.read_csv("984_gonogo.csv")
responseTime = gngLog['key_exp.rt']
gngLog = gngLog[['condition', 'corAns', 'key_exp.keys', 'unixbeg', 'unixend']]
gngLog['unixbeg'] = round(gngLog['unixbeg']/1000)
gngLog['unixend'] = round(gngLog['unixend']/1000)
gngLog
# Out:
#     condition corAns key_exp.keys       unixbeg       unixend
# 0          go  space          NaN  1.582734e+09  1.582734e+09
# 1          go  space          NaN  1.582734e+09  1.582734e+09
# 2        nogo   none          NaN  1.582734e+09  1.582734e+09
# 3          go  space          NaN  1.582734e+09  1.582734e+09
# 4          go  space          NaN  1.582734e+09  1.582734e+09
# ..        ...    ...          ...           ...           ...
# 327        go  space        space  1.582735e+09  1.582735e+09
# 328        go  space        space  1.582735e+09  1.582735e+09
# 329        go  space        space  1.582735e+09  1.582735e+09
# 330       NaN    NaN          NaN           NaN           NaN
# 331       NaN    NaN          NaN           NaN           NaN
#
# [332 rows x 5 columns]

# %%
# df.loc[df['B'] == 3, 'A']

# gngLog.iloc[3]

def refineLog():
    result = gngLog.copy()
    changes = False
    for i in range(len(result)):
        if(i<len(result)):
            if(result['corAns'].iloc[i] == "space" and result['corAns'].iloc[i+1] == "space"):
                result.at[i, 'unixend'] = result['unixend'].iloc[i+1]
                result.drop(index=i+1, inplace=True)
#     result.drop(result[result['corAns'].isna()].index, inplace=True)
    result = result[result['corAns'] != 'none']
    result = result.dropna(subset=['corAns'])
    result = result.reset_index(drop=True)


    return result

def getPeriodTime(start_unix, end_unix):
    
    print(start_unix)
    result = gngData.copy()
    result = result[(result['1'] >= start_unix-30) & (result['1'] <= end_unix+10)] 
    
    return result

def getBaseline(start_unix):
    print(start_unix)
    result = gngData.copy()
    startBaseline = start_unix - 25
    endBaseline = start_unix - 20
#     print("start", startBaseline)
#     print("end", endBaseline)
    result = result[(result['1'] >= startBaseline) & (result['1'] <= endBaseline)] 
    return result
    
#     print(begVal)

# %%
# Process:

# %%
# getPeriodTime()
gngLog
# Out:
#     condition corAns key_exp.keys       unixbeg       unixend
# 0          go  space          NaN  1.582734e+09  1.582734e+09
# 1          go  space          NaN  1.582734e+09  1.582734e+09
# 2        nogo   none          NaN  1.582734e+09  1.582734e+09
# 3          go  space          NaN  1.582734e+09  1.582734e+09
# 4          go  space          NaN  1.582734e+09  1.582734e+09
# ..        ...    ...          ...           ...           ...
# 327        go  space        space  1.582735e+09  1.582735e+09
# 328        go  space        space  1.582735e+09  1.582735e+09
# 329        go  space        space  1.582735e+09  1.582735e+09
# 330       NaN    NaN          NaN           NaN           NaN
# 331       NaN    NaN          NaN           NaN           NaN
#
# [332 rows x 5 columns]

# %%
z = refineLog()
z
# Out:
#     condition corAns key_exp.keys       unixbeg       unixend
# 0          go  space          NaN  1.582734e+09  1.582734e+09
# 1          go  space          NaN  1.582734e+09  1.582734e+09
# 2          go  space          NaN  1.582734e+09  1.582734e+09
# 3          go  space          NaN  1.582734e+09  1.582734e+09
# 4          go  space          NaN  1.582734e+09  1.582734e+09
# ..        ...    ...          ...           ...           ...
# 169        go  space        space  1.582735e+09  1.582735e+09
# 170        go  space        space  1.582735e+09  1.582735e+09
# 171        go  space        space  1.582735e+09  1.582735e+09
# 172        go  space        space  1.582735e+09  1.582735e+09
# 173        go  space        space  1.582735e+09  1.582735e+09
#
# [174 rows x 5 columns]

# %%
getPeriodTime(gngLog['unixbeg'].iloc[132], gngLog['unixend'].iloc[132])
# Out:
# 1582734585.0
#                   1          2         3          4          5         6  \
# 47250  1.582735e+09  28.750761  9.876713  38.627476  18.874048  5.284076
# 47251  1.582735e+09  28.764223  9.857728  38.621952  18.906494  5.284076
# 47252  1.582735e+09  28.749806  9.862822  38.612629  18.886984  5.290806
# 47253  1.582735e+09  28.742121  9.858422  38.600544  18.883698  5.276390
# 47254  1.582735e+09  28.748852  9.848930  38.597782  18.899921  5.276390
# ...             ...        ...       ...        ...        ...       ...
# 49296  1.582735e+09  28.878639  9.696355  38.574993  19.182285  5.896208
# 49297  1.582735e+09  28.864224  9.701448  38.565670  19.162775  5.888522
# 49298  1.582735e+09  28.849808  9.706541  38.556347  19.143267  5.874105
# 49299  1.582735e+09  28.856537  9.697049  38.553585  19.159489  5.866420
# 49300  1.582735e+09  28.856537  9.697049  38.553585  19.159489  5.852003
#
#               7         8         9         10  ...  Unnamed: 52  Unnamed: 53  \
# 47250  0.608998  5.892974  4.675088  38.448402  ...          NaN          NaN
# 47251  0.608998  5.892974  4.675088  38.455132  ...          NaN          NaN
# 47252  0.599506  5.890212  4.691310  38.433029  ...          NaN          NaN
# 47253  0.604599  5.880889  4.671801  38.432072  ...          NaN          NaN
# 47254  0.604599  5.880889  4.671801  38.424389  ...          NaN          NaN
# ...         ...       ...       ...        ...  ...          ...          ...
# 49296  0.599047  6.495155  5.297170  38.156082  ...          NaN          NaN
# 49297  0.594649  6.483070  5.293883  38.156082  ...          NaN          NaN
# 49298  0.599742  6.473748  5.274374  38.141666  ...          NaN          NaN
# 49299  0.595343  6.461663  5.271087  38.127251  ...          NaN          NaN
# 49300  0.600436  6.452340  5.251577  38.119564  ...          NaN          NaN
#
#        Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 47250          NaN          NaN          NaN          NaN          NaN
# 47251          NaN          NaN          NaN          NaN          NaN
# 47252          NaN          NaN          NaN          NaN          NaN
# 47253          NaN          NaN          NaN          NaN          NaN
# 47254          NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 49296          NaN          NaN          NaN          NaN          NaN
# 49297          NaN          NaN          NaN          NaN          NaN
# 49298          NaN          NaN          NaN          NaN          NaN
# 49299          NaN          NaN          NaN          NaN          NaN
# 49300          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 59  Unnamed: 60  Unnamed: 61
# 47250          NaN          NaN          NaN
# 47251          NaN          NaN          NaN
# 47252          NaN          NaN          NaN
# 47253          NaN          NaN          NaN
# 47254          NaN          NaN          NaN
# ...            ...          ...          ...
# 49296          NaN          NaN          NaN
# 49297          NaN          NaN          NaN
# 49298          NaN          NaN          NaN
# 49299          NaN          NaN          NaN
# 49300          NaN          NaN          NaN
#
# [2051 rows x 62 columns]

# %%
getBaseline(gngLog['unixbeg'].iloc[132])
# Out:
# 1582734585.0
#                   1          2         3          4          5         6  \
# 47500  1.582735e+09  29.035267  9.719276  38.754543  19.315990  5.513782
# 47501  1.582735e+09  29.035267  9.719276  38.754543  19.315990  5.513782
# 47502  1.582735e+09  29.042952  9.723676  38.766628  19.319277  5.528198
# 47503  1.582735e+09  29.029491  9.742662  38.772152  19.286831  5.542614
# 47504  1.582735e+09  29.029491  9.742662  38.772152  19.286831  5.542614
# ...             ...        ...       ...        ...        ...       ...
# 47746  1.582735e+09  29.088154  9.629445  38.717598  19.458710  5.594505
# 47747  1.582735e+09  29.088154  9.629445  38.717598  19.458710  5.586819
# 47748  1.582735e+09  29.088154  9.629445  38.717598  19.458710  5.586819
# 47749  1.582735e+09  29.080469  9.625046  38.705513  19.455423  5.579133
# 47750  1.582735e+09  29.072782  9.620646  38.693428  19.452137  5.564717
#
#               7         8         9         10  ...  Unnamed: 52  Unnamed: 53  \
# 47500  0.513611  6.027293  5.000181  38.522434  ...          NaN          NaN
# 47501  0.513611  6.027293  5.000181  38.522434  ...          NaN          NaN
# 47502  0.508518  6.036616  5.019691  38.529167  ...          NaN          NaN
# 47503  0.503424  6.045939  5.039200  38.543583  ...          NaN          NaN
# 47504  0.503424  6.045939  5.039200  38.542625  ...          NaN          NaN
# ...         ...       ...       ...        ...  ...          ...          ...
# 47746  0.506434  6.100839  5.088080  38.600376  ...          NaN          NaN
# 47747  0.502035  6.088754  5.084794  38.585960  ...          NaN          NaN
# 47748  0.502035  6.088754  5.084794  38.578274  ...          NaN          NaN
# 47749  0.497636  6.076669  5.081507  38.562900  ...          NaN          NaN
# 47750  0.502730  6.067347  5.061997  38.555218  ...          NaN          NaN
#
#        Unnamed: 54  Unnamed: 55  Unnamed: 56  Unnamed: 57  Unnamed: 58  \
# 47500          NaN          NaN          NaN          NaN          NaN
# 47501          NaN          NaN          NaN          NaN          NaN
# 47502          NaN          NaN          NaN          NaN          NaN
# 47503          NaN          NaN          NaN          NaN          NaN
# 47504          NaN          NaN          NaN          NaN          NaN
# ...            ...          ...          ...          ...          ...
# 47746          NaN          NaN          NaN          NaN          NaN
# 47747          NaN          NaN          NaN          NaN          NaN
# 47748          NaN          NaN          NaN          NaN          NaN
# 47749          NaN          NaN          NaN          NaN          NaN
# 47750          NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 59  Unnamed: 60  Unnamed: 61
# 47500          NaN          NaN          NaN
# 47501          NaN          NaN          NaN
# 47502          NaN          NaN          NaN
# 47503          NaN          NaN          NaN
# 47504          NaN          NaN          NaN
# ...            ...          ...          ...
# 47746          NaN          NaN          NaN
# 47747          NaN          NaN          NaN
# 47748          NaN          NaN          NaN
# 47749          NaN          NaN          NaN
# 47750          NaN          NaN          NaN
#
# [251 rows x 62 columns]

# %%
def getAverage(df):
    avg_values = df.mean()

# %%
avgVal = getAverage(getBaseline(gngLog['unixbeg'].iloc[132]))
# Out:
# 1582734585.0

# %%
diffColOne = gngData['2']
diffColOne
# Out:
# 0         136.770523
# 1         136.770523
# 2         136.770523
# 3         136.770523
# 4         136.770523
#              ...
# 109445     31.240822
# 109446     31.196617
# 109447     31.167786
# 109448     31.138952
# 109449     31.109165
# Name: 2, Length: 109450, dtype: float64

# %%
column_values = diffColOne

median_value = np.median(column_values)

below_median = column_values[column_values < median_value]
above_median = column_values[column_values >= median_value]

average_below = np.mean(below_median)
average_above = np.mean(above_median)

print("Average for values below the median:", average_below)
print("Average for values above the median:", average_above)
# Out:
# Average for values below the median: 28.83294427839978
# Average for values above the median: 37.70432352243121

# %%
z.iloc[6]
# Out:
# 0         136.770523
# 1         136.770523
# 2         136.770523
# 3         136.770523
# 4         136.770523
#              ...
# 109445     31.240822
# 109446     31.196617
# 109447     31.167786
# 109448     31.138952
# 109449     31.109165
# Name: 2, Length: 109450, dtype: float64

# %%
z.iloc[7]

# %%
z.iloc[8]

# %%
z.iloc[12]

# %%
def beerLambertLaw(df):
    wavelengths = [839, 757, 839, 757, 839, 757, 839, 757, 839, 757, 839, 757, 839, 757, 839, 757]
    ecOxy = 0.0055
    ecDeoxy = 0.0040 
    optodeDist = 35
    
    wavelength_cols = ['2', '3', '6', '7', '10', '11', '14', '15', '18', '19', '22', '23', '26', '27', '30', '31']

    oxy_data = pd.DataFrame()
    deoxy_data = pd.DataFrame()

    for i in range(0, len(wavelength_cols), 2):
        oxy_col = wavelength_cols[i]
        deoxy_col = wavelength_cols[i+1]

        PLF = optodeDist * 2

        oxy_conc = np.log(1 / (df[oxy_col] / df['1'])) / (ecOxy * PLF)
        deoxy_conc = np.log(1 / (df[deoxy_col] / df['1'])) / (ecDeoxy * PLF)

        oxy_data['wavelength ' + str(i//2+1)] = oxy_conc
        deoxy_data['wavelength ' + str(i//2+1)] = deoxy_conc

    processed_data = pd.concat([oxy_data, deoxy_data], axis=1)
    return processed_data

# %%
print(gngData.columns)

# %%
fgh = beerLambertLaw(gngData)
fgh

# %%
gngData

# %%
gngLog

# %%
correct = []

for i in range(len(gngLog)):
    if(gngLog['corAns'].iloc[i] == gngLog['key_exp.keys'].iloc[i]):
        correct.append(True)
    else:
        correct.append(False)

# %%
correct

# %%
# plt.scatter(correct, responseTime)

# # set the x and y labels
# plt.ylabel('Response Time')
# plt.xlabel('Correct')

# # show the plot
# plt.show()
